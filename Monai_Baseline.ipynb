# %%
#1環境確認
import torch
import monai
print("PyTorch version:", torch.__version__)
print("MONAI version:", monai.__version__)
print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
# Out:
# PyTorch version: 2.6.0+cu118
# MONAI version: 1.4.0
# CUDA available: True
# GPU: NVIDIA GeForce RTX 4060 Laptop GPU

# %%
# Import 和 Config
import os, random
from pathlib import Path
import numpy as np
import torch
import matplotlib.pyplot as plt

from monai.utils import set_determinism
from monai.transforms import (
    Compose, LoadImaged, EnsureChannelFirstd,
    NormalizeIntensityd, Lambdad, EnsureTyped, EnsureType,
    AsDiscrete, RandCropByPosNegLabeld, DivisiblePadd,
    RandAffined, RandFlipd
)
from monai.data import Dataset, DataLoader, decollate_batch
from monai.networks.nets import UNet
from monai.losses import DiceCELoss
from monai.metrics import DiceMetric
from monai.inferers import sliding_window_inference
from torch.optim.lr_scheduler import ReduceLROnPlateau

# ── 放入圖片的路徑 ──────────────────────────────
DATA_ROOT = r"D:\data mining datasets\Task01_BrainTumour\Task01_BrainTumour"
# ─────────────────────────────────────────────

IMG_DIR = Path(DATA_ROOT) / "imagesTr"
LBL_DIR = Path(DATA_ROOT) / "labelsTr"

MAX_EPOCHS    = 120
VAL_EVERY     = 5
ROI_SIZE      = (128, 128, 128)
SW_BS         = 4
LR            = 2e-4
WEIGHT_DECAY  = 1e-5
BATCH_SIZE    = 1
NUM_WORKERS   = 0
SEED          = 42

set_determinism(SEED)
torch.backends.cudnn.benchmark = False
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cuda

# %%
# Cell 3 - Baseline (無 augmentation)
all_images = sorted(IMG_DIR.glob("BRATS_*.nii.gz"))
pairs = []
for img in all_images:
    lab = LBL_DIR / img.name
    if lab.exists():
        pairs.append({"image": str(img), "label": str(lab)})

assert len(pairs) >= 10, f"Need >=10 cases, got {len(pairs)}"
rnd = random.Random(SEED)
rnd.shuffle(pairs)
split = max(1, int(len(pairs) * 0.8))
train_files, val_files = pairs[:split], pairs[split:]
print(f"Train: {len(train_files)} | Val: {len(val_files)}")

common_load = [
    LoadImaged(keys=["image", "label"]),
    EnsureChannelFirstd(keys=["image", "label"]),
    NormalizeIntensityd(keys=["image"], nonzero=True, channel_wise=True),
    Lambdad(keys="label", func=lambda x: (x > 0).astype(np.uint8)),
]

# Baseline：train 完全不加 augmentation
train_transforms = Compose(
    common_load + [
        RandCropByPosNegLabeld(
            keys=["image", "label"], label_key="label",
            spatial_size=(96, 96, 96), pos=4, neg=1, num_samples=4
        ),
        EnsureTyped(keys=["image", "label"]),
    ]
)

val_transforms = Compose(
    common_load + [
        DivisiblePadd(keys=["image", "label"], k=16),
        EnsureTyped(keys=["image", "label"]),
    ]
)

train_ds = Dataset(train_files, transform=train_transforms)
val_ds   = Dataset(val_files,   transform=val_transforms)

train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True,  num_workers=NUM_WORKERS)
val_loader   = DataLoader(val_ds,   batch_size=1,          shuffle=False, num_workers=NUM_WORKERS)
print("DataLoader ready ✅")
# Out:
# Train: 387 | Val: 97
# DataLoader ready ✅

# %%
# 4 Model / Loss / Optimizer
model = UNet(
    spatial_dims=3,
    in_channels=4,
    out_channels=1,
    channels=(16, 32, 64, 128, 256),
    strides=(2, 2, 2, 2),
    num_res_units=2,
).to(device)

criterion = DiceCELoss(
    sigmoid=True, to_onehot_y=False, include_background=False,
    squared_pred=True, smooth_nr=1e-5, smooth_dr=1e-5
)

optimizer = torch.optim.Adam(model.parameters(), lr=LR, weight_decay=WEIGHT_DECAY)
scheduler = ReduceLROnPlateau(optimizer, mode="max", factor=0.5, patience=6)

dice_metric = DiceMetric(include_background=False, reduction="mean", get_not_nans=False)
post_pred  = Compose([EnsureType(), AsDiscrete(threshold=0.5)])
post_label = Compose([EnsureType()])

print("Model ready ✅  Params:", sum(p.numel() for p in model.parameters()) // 1_000_000, "M")
# Out:
# Model ready ✅  Params: 4 M

# %%
#5 - Training Loop
train_losses, val_dices = [], []
best_dice, best_epoch = 0.0, -1

for ep in range(1, MAX_EPOCHS + 1):
    # ── Train ──────────────────────────────────
    model.train()
    epoch_loss, steps = 0.0, 0
    for batch in train_loader:
        img = batch["image"].to(device)
        lab = batch["label"].float().to(device)
        optimizer.zero_grad()
        logits = model(img)
        loss = criterion(logits, lab)
        loss.backward()
        # ✅ Gradient clipping：防止梯度爆炸
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        optimizer.step()
        epoch_loss += loss.item()
        steps += 1
    epoch_loss /= max(1, steps)
    train_losses.append(epoch_loss)

    # ── Validation（每 VAL_EVERY epochs）──────
    if ep % VAL_EVERY == 0:
        model.eval()
        dice_metric.reset()
        with torch.no_grad():
            for batch in val_loader:   # ✅ 修正：跑完整 val set，不是單一 case
                img = batch["image"].to(device)
                lab = batch["label"].float().to(device)
                logits = sliding_window_inference(
                    img, roi_size=ROI_SIZE, sw_batch_size=SW_BS,
                    predictor=model, overlap=0.5
                )
                prob = torch.sigmoid(logits)
                preds = [post_pred(x) for x in decollate_batch(prob)]
                gts   = [post_label(x) for x in decollate_batch(lab)]
                dice_metric(y_pred=preds, y=gts)

        mean_dice = float(dice_metric.aggregate().item())
        val_dices.append(mean_dice)
        scheduler.step(mean_dice)

        if mean_dice > best_dice:
            best_dice, best_epoch = mean_dice, ep
            torch.save({"epoch": ep, "model": model.state_dict(), "dice": mean_dice}, "best_baseline.pth")
            print(f"  ★ New best saved!")

        print(f"Epoch {ep:03d}/{MAX_EPOCHS} | LR {optimizer.param_groups[0]['lr']:.2e} "
              f"| TrainLoss {epoch_loss:.4f} | ValDice {mean_dice:.4f}")
    else:
        print(f"Epoch {ep:03d}/{MAX_EPOCHS} | TrainLoss {epoch_loss:.4f}")

print(f"\n✅ Best ValDice: {best_dice:.4f} @ epoch {best_epoch}")
# Out:
# single channel prediction, `include_background=False` ignored.
# Epoch 001/120 | TrainLoss 1.1780
# Epoch 002/120 | TrainLoss 1.0463
# Epoch 003/120 | TrainLoss 0.8819
# Epoch 004/120 | TrainLoss 0.8017
#   ★ New best saved!
# Epoch 005/120 | LR 2.00e-04 | TrainLoss 0.6747 | ValDice 0.6352
# Epoch 006/120 | TrainLoss 0.5847
# Epoch 007/120 | TrainLoss 0.5261
# Epoch 008/120 | TrainLoss 0.4737
# Epoch 009/120 | TrainLoss 0.4574
#   ★ New best saved!
# Epoch 010/120 | LR 2.00e-04 | TrainLoss 0.3991 | ValDice 0.6909
# Epoch 011/120 | TrainLoss 0.3977
# Epoch 012/120 | TrainLoss 0.3530
# Epoch 013/120 | TrainLoss 0.3553
# Epoch 014/120 | TrainLoss 0.3585
# Epoch 015/120 | LR 2.00e-04 | TrainLoss 0.3342 | ValDice 0.5781
# Epoch 016/120 | TrainLoss 0.3117
# Epoch 017/120 | TrainLoss 0.2720
# Epoch 018/120 | TrainLoss 0.2576
# Epoch 019/120 | TrainLoss 0.2465
#   ★ New best saved!
# Epoch 020/120 | LR 2.00e-04 | TrainLoss 0.2271 | ValDice 0.8895
# Epoch 021/120 | TrainLoss 0.2271
# Epoch 022/120 | TrainLoss 0.2392
# Epoch 023/120 | TrainLoss 0.2106
# Epoch 024/120 | TrainLoss 0.2109
# Epoch 025/120 | LR 2.00e-04 | TrainLoss 0.2114 | ValDice 0.8837
# Epoch 026/120 | TrainLoss 0.2222
# Epoch 027/120 | TrainLoss 0.2068
# Epoch 028/120 | TrainLoss 0.2085
# Epoch 029/120 | TrainLoss 0.2052
#   ★ New best saved!
# Epoch 030/120 | LR 2.00e-04 | TrainLoss 0.1979 | ValDice 0.8914
# Epoch 031/120 | TrainLoss 0.2000
# Epoch 032/120 | TrainLoss 0.1974
# Epoch 033/120 | TrainLoss 0.1992
# Epoch 034/120 | TrainLoss 0.2103
#   ★ New best saved!
# Epoch 035/120 | LR 2.00e-04 | TrainLoss 0.1956 | ValDice 0.9031
# Epoch 036/120 | TrainLoss 0.2031
# Epoch 037/120 | TrainLoss 0.1946
# Epoch 038/120 | TrainLoss 0.1870
# Epoch 039/120 | TrainLoss 0.1850
# Epoch 040/120 | LR 2.00e-04 | TrainLoss 0.1997 | ValDice 0.9015
# Epoch 041/120 | TrainLoss 0.1906
# Epoch 042/120 | TrainLoss 0.1956
# Epoch 043/120 | TrainLoss 0.1813
# Epoch 044/120 | TrainLoss 0.1896
#   ★ New best saved!
# Epoch 045/120 | LR 2.00e-04 | TrainLoss 0.1950 | ValDice 0.9080
# Epoch 046/120 | TrainLoss 0.1938
# Epoch 047/120 | TrainLoss 0.1858
# Epoch 048/120 | TrainLoss 0.1831
# Epoch 049/120 | TrainLoss 0.1802
# Epoch 050/120 | LR 2.00e-04 | TrainLoss 0.1792 | ValDice 0.8917
# Epoch 051/120 | TrainLoss 0.1943
# Epoch 052/120 | TrainLoss 0.1854
# Epoch 053/120 | TrainLoss 0.1778
# Epoch 054/120 | TrainLoss 0.1839
# Epoch 055/120 | LR 2.00e-04 | TrainLoss 0.1915 | ValDice 0.9038
# Epoch 056/120 | TrainLoss 0.1860
# Epoch 057/120 | TrainLoss 0.1954
# Epoch 058/120 | TrainLoss 0.1840
# Epoch 059/120 | TrainLoss 0.1667
#   ★ New best saved!
# Epoch 060/120 | LR 2.00e-04 | TrainLoss 0.1760 | ValDice 0.9089
# Epoch 061/120 | TrainLoss 0.1753
# Epoch 062/120 | TrainLoss 0.1723
# Epoch 063/120 | TrainLoss 0.1845
# Epoch 064/120 | TrainLoss 0.1906
# Epoch 065/120 | LR 2.00e-04 | TrainLoss 0.1654 | ValDice 0.9061
# Epoch 066/120 | TrainLoss 0.1791
# Epoch 067/120 | TrainLoss 0.1726
# Epoch 068/120 | TrainLoss 0.1890
# Epoch 069/120 | TrainLoss 0.1898
# Epoch 070/120 | LR 2.00e-04 | TrainLoss 0.1810 | ValDice 0.9048
# Epoch 071/120 | TrainLoss 0.1913
# Epoch 072/120 | TrainLoss 0.1885
# Epoch 073/120 | TrainLoss 0.1831
# Epoch 074/120 | TrainLoss 0.1712
# Epoch 075/120 | LR 2.00e-04 | TrainLoss 0.1794 | ValDice 0.9084
# Epoch 076/120 | TrainLoss 0.1732
# Epoch 077/120 | TrainLoss 0.1757
# Epoch 078/120 | TrainLoss 0.1928
# Epoch 079/120 | TrainLoss 0.1781
#   ★ New best saved!
# Epoch 080/120 | LR 2.00e-04 | TrainLoss 0.1778 | ValDice 0.9101
# Epoch 081/120 | TrainLoss 0.1688
# Epoch 082/120 | TrainLoss 0.1754
# Epoch 083/120 | TrainLoss 0.1906
# Epoch 084/120 | TrainLoss 0.1622
#   ★ New best saved!
# Epoch 085/120 | LR 2.00e-04 | TrainLoss 0.1699 | ValDice 0.9104
# Epoch 086/120 | TrainLoss 0.1816
# Epoch 087/120 | TrainLoss 0.1663
# Epoch 088/120 | TrainLoss 0.1793
# Epoch 089/120 | TrainLoss 0.1766
# Epoch 090/120 | LR 2.00e-04 | TrainLoss 0.1712 | ValDice 0.8963
# Epoch 091/120 | TrainLoss 0.1705
# Epoch 092/120 | TrainLoss 0.1704
# Epoch 093/120 | TrainLoss 0.1661
# Epoch 094/120 | TrainLoss 0.1706
# Epoch 095/120 | LR 2.00e-04 | TrainLoss 0.1710 | ValDice 0.9096
# Epoch 096/120 | TrainLoss 0.1822
# Epoch 097/120 | TrainLoss 0.1672
# Epoch 098/120 | TrainLoss 0.1723
# Epoch 099/120 | TrainLoss 0.1682
# Epoch 100/120 | LR 2.00e-04 | TrainLoss 0.1700 | ValDice 0.9083
# Epoch 101/120 | TrainLoss 0.1707
# Epoch 102/120 | TrainLoss 0.1717
# Epoch 103/120 | TrainLoss 0.1721
# Epoch 104/120 | TrainLoss 0.1710
#   ★ New best saved!
# Epoch 105/120 | LR 2.00e-04 | TrainLoss 0.1825 | ValDice 0.9141
# Epoch 106/120 | TrainLoss 0.1631
# Epoch 107/120 | TrainLoss 0.1680
# Epoch 108/120 | TrainLoss 0.1691
# Epoch 109/120 | TrainLoss 0.1606
# Epoch 110/120 | LR 2.00e-04 | TrainLoss 0.1695 | ValDice 0.9081
# Epoch 111/120 | TrainLoss 0.1679
# Epoch 112/120 | TrainLoss 0.1735
# Epoch 113/120 | TrainLoss 0.1691
# Epoch 114/120 | TrainLoss 0.1586
# Epoch 115/120 | LR 2.00e-04 | TrainLoss 0.1672 | ValDice 0.9059
# Epoch 116/120 | TrainLoss 0.1661
# Epoch 117/120 | TrainLoss 0.1627
# Epoch 118/120 | TrainLoss 0.1691
# Epoch 119/120 | TrainLoss 0.1593
# Epoch 120/120 | LR 2.00e-04 | TrainLoss 0.1642 | ValDice 0.9131
#
# ✅ Best ValDice: 0.9141 @ epoch 105

# %%
# Cell 6 - 畫圖
val_epochs = list(range(VAL_EVERY, MAX_EPOCHS + 1, VAL_EVERY))

fig, ax1 = plt.subplots(figsize=(12, 5))
ax1.plot(range(1, MAX_EPOCHS + 1), train_losses, color="steelblue", label="Train Loss")
ax1.set_xlabel("Epoch")
ax1.set_ylabel("Loss", color="steelblue")
ax1.tick_params(axis="y", labelcolor="steelblue")

ax2 = ax1.twinx()
ax2.plot(val_epochs, val_dices, color="tomato", marker="o", label="Val Dice")
ax2.set_ylabel("Dice", color="tomato")
ax2.tick_params(axis="y", labelcolor="tomato")
ax2.set_ylim(0, 1)
ax2.axhline(y=best_dice, color="tomato", linestyle="--", alpha=0.5, label=f"Best={best_dice:.4f}")

fig.legend(loc="upper right", bbox_to_anchor=(0.88, 0.88))
plt.title("Binary BraTS Segmentation - Training Curve")
plt.tight_layout()
plt.savefig("training_curve.png", dpi=150)
plt.show()
print(f"Best ValDice: {best_dice:.4f} @ epoch {best_epoch}")
# Out:
# Best ValDice: 0.9141 @ epoch 105
